# %%
import pandas as pd 
import numpy as np

data = pd.read_csv('HistoricalDataExport_20241107_024541.csv')
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#                        Company Name  Customer Class  \
# 0  Direct Energy Regulated Services            Home
# 1  Direct Energy Regulated Services  Small Business
# 2  Direct Energy Regulated Services            Farm
# 3      EPCOR Energy Alberta GP Inc.            Home
# 4      EPCOR Energy Alberta GP Inc.  Small Business
# 5      EPCOR Energy Alberta GP Inc.            Home
# 6      EPCOR Energy Alberta GP Inc.  Small Business
# 7      EPCOR Energy Alberta GP Inc.            Farm
# 8      EPCOR Energy Alberta GP Inc.            Farm
# 9                     Adagio Energy            Home
#
#                                             Product  \
# 0      DERS Regulated Electricity Rate January 2024
# 1      DERS Regulated Electricity Rate January 2024
# 2      DERS Regulated Electricity Rate January 2024
# 3  January Regulated Rate Option - City of Edmonton
# 4  January Regulated Rate Option - City of Edmonton
# 5  January Regulated Rate Option - Outside Edmonton
# ...
